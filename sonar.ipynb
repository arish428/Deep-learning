# %% [markdown]
# <a href="https://colab.research.google.com/github/arish428/Deep-learning/blob/main/sonar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3a2b2e62-da2e-46fc-9e20-6648cbf7cfb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a2b2e62-da2e-46fc-9e20-6648cbf7cfb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Binary.csv to Binary (4).csv

# %%
len(uploaded)
# Out:
# 1

# %%
data = pd.read_csv(io.BytesIO(uploaded['Binary.csv']))

# %%
data.shape
# 207 rows and 61 columns
# Out:
# (207, 61)

# %%
shuffle_data = data.sample(frac = 1)
shuffle_data
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032  R
# 151  0.0131  0.0201  0.0045  0.0217  0.0230  ...  0.0030  0.0066  0.0029  0.0053  M
# 57   0.0225  0.0019  0.0075  0.0097  0.0445  ...  0.0030  0.0035  0.0021  0.0027  R
# 157  0.0107  0.0453  0.0289  0.0713  0.1075  ...  0.0072  0.0060  0.0017  0.0036  M
# 188  0.0158  0.0239  0.0150  0.0494  0.0988  ...  0.0034  0.0046  0.0022  0.0021  M
# 86   0.0856  0.0454  0.0382  0.0203  0.0385  ...  0.0258  0.0102  0.0037  0.0037  R
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...     ... ..
# 40   0.0093  0.0185  0.0056  0.0064  0.0260  ...  0.0089  0.0050  0.0058  0.0025  R
# 123  0.0388  0.0324  0.0688  0.0898  0.1267  ...  0.0107  0.0068  0.0097  0.0067  M
# 19   0.0473  0.0509  0.0819  0.1252  0.1783  ...  0.0049  0.0082  0.0028  0.0027  R
# 173  0.0191  0.0173  0.0291  0.0301  0.0463  ...  0.0110  0.0122  0.0114  0.0068  M
# ...

# %%
encoded_data= shuffle_data.replace({"M":0,"R":1})
encoded_data.iloc[:,-1]
# Out:
# 151    0
# 57     1
# 157    0
# 188    0
# 86     1
#       ..
# 40     1
# 123    0
# 19     1
# 173    0
# 171    0
# Name: R, Length: 207, dtype: int64

# %%
y_data = encoded_data.iloc[:,-1]
y_labels.ndim
# Out:
# 1

# %%
x_train = encoded_data.iloc[:int(final_data.shape[0]*0.7),0:60]
x_train
# Out:
#      0.0200  0.0371  0.0428  0.0207  ...  0.0180  0.0084  0.0090  0.0032
# 151  0.0131  0.0201  0.0045  0.0217  ...  0.0030  0.0066  0.0029  0.0053
# 57   0.0225  0.0019  0.0075  0.0097  ...  0.0030  0.0035  0.0021  0.0027
# 157  0.0107  0.0453  0.0289  0.0713  ...  0.0072  0.0060  0.0017  0.0036
# 188  0.0158  0.0239  0.0150  0.0494  ...  0.0034  0.0046  0.0022  0.0021
# 86   0.0856  0.0454  0.0382  0.0203  ...  0.0258  0.0102  0.0037  0.0037
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 148  0.0207  0.0535  0.0334  0.0818  ...  0.0042  0.0090  0.0070  0.0099
# 193  0.0392  0.0108  0.0267  0.0257  ...  0.0071  0.0044  0.0022  0.0014
# 170  0.0179  0.0136  0.0408  0.0633  ...  0.0081  0.0155  0.0160  0.0085
# 175  0.0635  0.0709  0.0453  0.0333  ...  0.0086  0.0085  0.0040  0.0051
# 52   0.0293  0.0378  0.0257  0.0062  ...  0.0041  0.0055  0.0050  0.0087
#
# [144 rows x 60 columns]

# %%
x_test = encoded_data.iloc[int(final_data.shape[0]*0.7):,0:60]
x_test
# Out:
#      0.0200  0.0371  0.0428  0.0207  ...  0.0180  0.0084  0.0090  0.0032
# 136  0.0430  0.0902  0.0833  0.0813  ...  0.0027  0.0162  0.0059  0.0021
# 49   0.0353  0.0713  0.0326  0.0272  ...  0.0037  0.0096  0.0093  0.0053
# 28   0.0189  0.0308  0.0197  0.0622  ...  0.0099  0.0092  0.0052  0.0075
# 109  0.0210  0.0121  0.0203  0.1036  ...  0.0080  0.0107  0.0161  0.0133
# 64   0.0176  0.0172  0.0501  0.0285  ...  0.0112  0.0179  0.0294  0.0063
# ..      ...     ...     ...     ...  ...     ...     ...     ...     ...
# 40   0.0093  0.0185  0.0056  0.0064  ...  0.0089  0.0050  0.0058  0.0025
# 123  0.0388  0.0324  0.0688  0.0898  ...  0.0107  0.0068  0.0097  0.0067
# 19   0.0473  0.0509  0.0819  0.1252  ...  0.0049  0.0082  0.0028  0.0027
# 173  0.0191  0.0173  0.0291  0.0301  ...  0.0110  0.0122  0.0114  0.0068
# 171  0.0180  0.0444  0.0476  0.0698  ...  0.0026  0.0050  0.0073  0.0022
#
# [63 rows x 60 columns]

# %%
# trainingx      testingx      trainingy      testingy
# testing 70%
# training 30%

final_data.shape[0]
final_data.shape
# Out:
# (207, 61)

# %%
# x_data = int(final_data.shape[0]*0.7)
# y_data = int(final_data.shape[0]*0.3)
# print(x_data,y_data) 
y_labels.shape
# Out:
# (207,)

# %%
# x_data.iloc[:,int(final_data.shape[0]*0.7),0:60]

# %%
y_train = y_labels.iloc[:int(y_labels.shape[0]*0.7)]
y_test  = y_labels.iloc[int(y_labels.shape[0]*0.7):]

# %%
y_train
# Out:
# 126    0
# 55     1
# 194    0
# 80     1
# 1      1
#       ..
# 64     1
# 96     0
# 11     1
# 18     1
# 156    0
# Name: R, Length: 144, dtype: int64

# %%
y_test
# Out:
# 92     1
# 119    0
# 0      1
# 54     1
# 178    0
#       ..
# 17     1
# 67     1
# 121    0
# 179    0
# 90     1
# Name: R, Length: 63, dtype: int64

# %%
y_train.shape
# Out:
# (144,)

# %%
y_test.shape
# Out:
# (63,)

# %%
from keras import models
from keras import layers
network = models.Sequential()
network.add(layers.Dense(256, activation='relu', input_shape=(60,)))
network.add(layers.Dense(128, activation='relu'))
network.add(layers.Dense(64, activation='relu'))
network.add(layers.Dense(1, activation='sigmoid'))

# %%
network.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
 network.fit(x_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6446 - accuracy: 0.6111
# Epoch 2/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6520 - accuracy: 0.6528
# Epoch 3/15
# 5/5 [==============================] - 0s 5ms/step - loss: 0.6195 - accuracy: 0.6528
# Epoch 4/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6195 - accuracy: 0.6875
# Epoch 5/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6182 - accuracy: 0.6667
# Epoch 6/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6141 - accuracy: 0.6458
# Epoch 7/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5958 - accuracy: 0.6736
# Epoch 8/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5701 - accuracy: 0.7083
# Epoch 9/15
# 5/5 [==============================] - 0s 3ms/step - loss: 0.5502 - accuracy: 0.7222
# Epoch 10/15
# ...
